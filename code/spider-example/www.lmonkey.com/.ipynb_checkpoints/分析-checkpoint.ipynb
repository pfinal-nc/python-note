# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv')
df
# Out:
#                             问题名称           URL    浏览量  标签
# 0       22道 JavaScript 面试常被问到的问题  /t/RLb2j2qLz     91  其他
# 1                      js经典面试题汇总  /t/xEO8j84yj     93  其他
# 2                  比较经典的Js面试题大汇总  /t/NLXvjvxEV     91  其他
# 3    20个必会的JavaScript面试题（你能做对几道）  /t/REQnjnGy1     71  其他
# 4                  前端面试题系列-- JS篇  /t/AL2xYxzER     85  其他
# ..                           ...           ...    ...  ..
# 595        win10  MySQLroot 远程连接  /t/PE6vYJYEg  71984  其他
# 596                        Day03  /t/zLAm3QxLW  15455  其他
# 597                        矩阵零空间  /t/xLPvD6qEe  43580  其他
# 598                   测试计划的设计和编写  /t/OLM2oe1Bd   9712  其他
# 599              Windows 命令行常用命令  /t/OLM2jKoBd  14377  其他
#
# [600 rows x 4 columns]

# %%
# 可视化分析
from pyecharts.charts import Bar,Map,Line,Page,Scatter,Pie,Polar
from pyecharts import options as opts
from pyecharts.globals import SymbolType,ThemeType
from pyecharts.charts import Grid

group = df.groupby('标签')

x_data = group.dtypes.index.tolist()
x_data
y_data = group.size().tolist()
y_data

c = (
    Pie()
    .add("", [list(z) for z in zip(x_data, y_data)])
    .set_global_opts(title_opts=opts.TitleOpts(title="Pie-文章分析"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e57a7a944e9b4e02889dc4325cde2d3f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e57a7a944e9b4e02889dc4325cde2d3f = echarts.init(
#                     document.getElementById('e57a7a944e9b4e02889dc4325cde2d3f'), 'white', {renderer: 'canvas'});
#                 var option_e57a7a944e9b4e02889dc4325cde2d3f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "Linux\u4e91\u8ba1\u7b97",
#                     "value": 22
#                 },
#                 {
#                     "name": "Web\u524d\u7aef",
#                     "value": 344
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 222
#                 },
#                 {
#                     "name": "\u6570\u636e\u5e93",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u733f\u751f\u6001",
#                     "value": 2
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Linux\u4e91\u8ba1\u7b97",
#                 "Web\u524d\u7aef",
#                 "\u5176\u4ed6",
#                 "\u6570\u636e\u5e93",
#                 "\u733f\u751f\u6001"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "Pie-\u6587\u7ae0\u5206\u6790",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_e57a7a944e9b4e02889dc4325cde2d3f.setOption(option_e57a7a944e9b4e02889dc4325cde2d3f);
#         });
#     </script>
